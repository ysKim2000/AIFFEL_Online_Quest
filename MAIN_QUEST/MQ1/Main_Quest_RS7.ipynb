# %% [markdown]
# # 프로젝트 : 폐렴 진단기 성능개선

# %% [markdown]
# ### 목차
# - Step 1. 실험환경 Set-up
# - Step 2. 데이터 준비하기
# - Step 3. 데이터 시각화
# - Step 4. ResNet 모델 구현
# - Step 5. 데이터 Imbalance
# - Step 6. 모델 훈련
# - Step 7. 평가 및 훈련 결과 시각화

# %% [markdown]
# ## Step 1. 실험환경 Set-up

# %% [markdown]
# ### 라이브러리 불러오기

# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### 변수 설정 및 데이터 로드

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 32
EPOCHS = 30

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ## Step 2. 데이터 준비하기

# %% [markdown]
# ### 데이터 전처리

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1070
# Pneumonia images count in training set: 3115

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %% [markdown]
# ### Augmentation

# %%
def augment(image,label):
    image = tf.image.random_flip_left_right(image)  # 랜덤하게 좌우를 반전합니다.
    
    return image,label

def prepare_for_training_aug(ds, shuffle_buffer_size=1000):
    # augment 적용 부분이 배치처리 함수에 추가되었습니다.
    ds = ds.map(
            augment,       # augment 함수 적용
            num_parallel_calls=2
        )
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

train_aug_ds = prepare_for_training_aug(train_ds)
val_aug_ds = prepare_for_training_aug(val_ds)

# %% [markdown]
# ## Step 3. 데이터 시각화

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### augmentation

# %%
image_aug_batch, label_aug_batch = next(iter(train_aug_ds))

def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    print(image_batch.shape)
    print(label_batch.shape)
    for n in range(16):
        ax = plt.subplot(5,5,n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")

show_batch(image_aug_batch.numpy(), label_aug_batch.numpy())
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# ## Step. 4 ResNet Model 구현

# %%
def residual_block(layer, filters, kernel_size=3, stride=2):
    x = tf.keras.layers.Conv2D(filters, kernel_size, strides=stride, padding='same')(layer)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Activation('relu')(x)

    x = tf.keras.layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    # Adding the shortcut (residual connection)
    shortcut = tf.keras.layers.Conv2D(filters, 1, strides=stride, padding='same')(layer)
    shortcut = tf.keras.layers.BatchNormalization()(shortcut)

    x = tf.keras.layers.Add()([x, shortcut])
    x = tf.keras.layers.Activation('relu')(x)
    
    return x

# %%
def dense_block(layer, units, dropout_rate=0.5, dropout=True):
    x = tf.keras.layers.Dense(units, activation='relu')(layer)
    x = tf.keras.layers.BatchNormalization()(x)
    if dropout:
        x = tf.keras.layers.Dropout(dropout_rate)(x)
    
    return x

# %%
def build_resnet_model():
    input_layer = tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3))

    x = tf.keras.layers.Conv2D(64, 7, strides=2, activation='relu', padding='same')(input_layer)
    x = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same')(x)

    # Using residual blocks instead of conv blocks
    x = residual_block(x, 64)
    x = residual_block(x, 64)
    
    x = residual_block(x, 128, stride=2)
    x = residual_block(x, 128)
    
    x = residual_block(x, 256, stride=2)
    x = residual_block(x, 256)
    
    x = residual_block(x, 512, stride=2)
    x = residual_block(x, 512)

    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = dense_block(x, 512, 0.7)
    x = dense_block(x, 128, 0.5)
    x = dense_block(x, 64, 0.3)

    output = tf.keras.layers.Dense(1, activation='sigmoid')(x)

    model = tf.keras.Model(inputs=input_layer, outputs=output)

    return model

# %%
build_resnet_model().summary()

# %% [markdown]
# ## Step 5. 데이터 Imbalance

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.96
# Weight for class 1: 0.67

# %% [markdown]
# ## Step 6. Train

# %% [markdown]
# #### resnet, drop out, augmentation result

# %%
with tf.device('/GPU:0'):
    resnet_model = build_resnet_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    resnet_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = resnet_model.fit(
        train_aug_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_aug_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/30
# 130/130 [==============================] - 70s 410ms/step - loss: 0.4005 - accuracy: 0.8055 - precision: 0.9406 - recall: 0.7884 - val_loss: 0.8250 - val_accuracy: 0.7324 - val_precision: 0.7324 - val_recall: 1.0000
# Epoch 2/30
# 130/130 [==============================] - 54s 419ms/step - loss: 0.2158 - accuracy: 0.9216 - precision: 0.9718 - recall: 0.9216 - val_loss: 0.6840 - val_accuracy: 0.7471 - val_precision: 0.7441 - val_recall: 1.0000
# Epoch 3/30
# 130/130 [==============================] - 55s 423ms/step - loss: 0.1918 - accuracy: 0.9303 - precision: 0.9759 - recall: 0.9292 - val_loss: 0.1379 - val_accuracy: 0.9482 - val_precision: 0.9473 - val_recall: 0.9840
# Epoch 4/30
# 130/130 [==============================] - 56s 436ms/step - loss: 0.1575 - accuracy: 0.9447 - precision: 0.9812 - recall: 0.9438 - val_loss: 0.2267 - val_accuracy: 0.9102 - val_precision: 0.8923 - val_recall: 0.9973
# Epoch 5/30
# 130/130 [==============================] - 58s 446ms/step - loss: 0.1269 - accuracy: 0.9534 - precision: 0.9846 - recall: 0.9522 - val_loss: 0.2001 - val_accuracy: 0.9385 - val_precision: 0.9873 - val_recall: 0.9281
# Epoch 6/30
# 130/130 [==============================] - 51s 392ms/step - loss: 0.1059 - accuracy: 0.9685 - precision: 0.9885 - recall: 0.9690 - val_loss: 0.6821 - val_accuracy: 0.7793 - val_precision: 0.7694 - val_recall: 1.0000
# Epoch 7/30
# 130/130 [==============================] - 50s 387ms/step - loss: 0.1208 - accuracy: 0.9558 - precision: 0.9850 - recall: 0.9552 - val_loss: 0.1368 - val_accuracy: 0.9541 - val_precision: 0.9431 - val_recall: 0.9973
# Epoch 8/30
# 130/130 [==============================] - 48s 375ms/step - loss: 0.1257 - accuracy: 0.9495 - precision: 0.9845 - recall: 0.9468 - val_loss: 0.2022 - val_accuracy: 0.9336 - val_precision: 0.9872 - val_recall: 0.9219
# Epoch 9/30
# 130/130 [==============================] - 51s 395ms/step - loss: 0.1045 - accuracy: 0.9642 - precision: 0.9894 - recall: 0.9623 - val_loss: 1.3824 - val_accuracy: 0.4951 - val_precision: 1.0000 - val_recall: 0.3125
# Epoch 10/30
# 130/130 [==============================] - 50s 384ms/step - loss: 0.1084 - accuracy: 0.9642 - precision: 0.9881 - recall: 0.9636 - val_loss: 1.5713 - val_accuracy: 0.5410 - val_precision: 1.0000 - val_recall: 0.3742
# Epoch 11/30
# 130/130 [==============================] - 49s 378ms/step - loss: 0.0870 - accuracy: 0.9695 - precision: 0.9917 - recall: 0.9669 - val_loss: 0.2098 - val_accuracy: 0.9180 - val_precision: 0.9897 - val_recall: 0.8972
# Epoch 12/30
# 130/130 [==============================] - 48s 373ms/step - loss: 0.0808 - accuracy: 0.9700 - precision: 0.9898 - recall: 0.9697 - val_loss: 0.1170 - val_accuracy: 0.9600 - val_precision: 0.9958 - val_recall: 0.9492
# Epoch 13/30
# 130/130 [==============================] - 52s 399ms/step - loss: 0.0747 - accuracy: 0.9724 - precision: 0.9934 - recall: 0.9694 - val_loss: 0.1084 - val_accuracy: 0.9590 - val_precision: 0.9550 - val_recall: 0.9907
# Epoch 14/30
# 130/130 [==============================] - 49s 383ms/step - loss: 0.0906 - accuracy: 0.9637 - precision: 0.9894 - recall: 0.9617 - val_loss: 0.5044 - val_accuracy: 0.8340 - val_precision: 0.8156 - val_recall: 1.0000
# Epoch 15/30
# 130/130 [==============================] - 50s 389ms/step - loss: 0.0637 - accuracy: 0.9800 - precision: 0.9944 - recall: 0.9787 - val_loss: 0.2124 - val_accuracy: 0.9121 - val_precision: 0.9955 - val_recall: 0.8846
# Epoch 16/30
# 130/130 [==============================] - 49s 378ms/step - loss: 0.0698 - accuracy: 0.9769 - precision: 0.9931 - recall: 0.9757 - val_loss: 0.5778 - val_accuracy: 0.8291 - val_precision: 0.8106 - val_recall: 1.0000
# Epoch 17/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0945 - accuracy: 0.9654 - precision: 0.9894 - recall: 0.9639 - val_loss: 0.1154 - val_accuracy: 0.9600 - val_precision: 0.9526 - val_recall: 0.9947
# Epoch 18/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0749 - accuracy: 0.9724 - precision: 0.9917 - recall: 0.9708 - val_loss: 0.1900 - val_accuracy: 0.9434 - val_precision: 0.9915 - val_recall: 0.9307
# Epoch 19/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0729 - accuracy: 0.9740 - precision: 0.9941 - recall: 0.9710 - val_loss: 0.1697 - val_accuracy: 0.9248 - val_precision: 0.9884 - val_recall: 0.9080
# Epoch 20/30
# 130/130 [==============================] - 50s 385ms/step - loss: 0.0619 - accuracy: 0.9762 - precision: 0.9940 - recall: 0.9738 - val_loss: 0.1070 - val_accuracy: 0.9590 - val_precision: 0.9797 - val_recall: 0.9640
# Epoch 21/30
# 130/130 [==============================] - 50s 387ms/step - loss: 0.0675 - accuracy: 0.9769 - precision: 0.9944 - recall: 0.9745 - val_loss: 0.2206 - val_accuracy: 0.9404 - val_precision: 0.9289 - val_recall: 0.9947
# Epoch 22/30
# 130/130 [==============================] - 49s 382ms/step - loss: 0.0754 - accuracy: 0.9750 - precision: 0.9934 - recall: 0.9729 - val_loss: 0.2583 - val_accuracy: 0.9062 - val_precision: 0.9985 - val_recall: 0.8737
# Epoch 23/30
# 130/130 [==============================] - 49s 377ms/step - loss: 0.0535 - accuracy: 0.9815 - precision: 0.9954 - recall: 0.9796 - val_loss: 2.8972 - val_accuracy: 0.4902 - val_precision: 0.9956 - val_recall: 0.3025
# Epoch 24/30
# 130/130 [==============================] - 48s 372ms/step - loss: 0.0639 - accuracy: 0.9767 - precision: 0.9934 - recall: 0.9751 - val_loss: 0.0945 - val_accuracy: 0.9727 - val_precision: 0.9726 - val_recall: 0.9907
# Epoch 25/30
# 130/130 [==============================] - 50s 389ms/step - loss: 0.0444 - accuracy: 0.9887 - precision: 0.9961 - recall: 0.9888 - val_loss: 0.3200 - val_accuracy: 0.8936 - val_precision: 0.8741 - val_recall: 0.9987
# Epoch 26/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0344 - accuracy: 0.9875 - precision: 0.9977 - recall: 0.9853 - val_loss: 0.1012 - val_accuracy: 0.9697 - val_precision: 0.9641 - val_recall: 0.9960
# Epoch 27/30
# 130/130 [==============================] - 50s 386ms/step - loss: 0.0804 - accuracy: 0.9776 - precision: 0.9954 - recall: 0.9746 - val_loss: 0.0679 - val_accuracy: 0.9766 - val_precision: 0.9892 - val_recall: 0.9787
# Epoch 28/30
# 130/130 [==============================] - 49s 375ms/step - loss: 0.0577 - accuracy: 0.9805 - precision: 0.9944 - recall: 0.9794 - val_loss: 0.2293 - val_accuracy: 0.9102 - val_precision: 0.9094 - val_recall: 0.9747
# Epoch 29/30
# 130/130 [==============================] - 50s 391ms/step - loss: 0.0512 - accuracy: 0.9812 - precision: 0.9948 - recall: 0.9800 - val_loss: 0.3401 - val_accuracy: 0.8721 - val_precision: 0.9968 - val_recall: 0.8280
# Epoch 30/30
# 130/130 [==============================] - 50s 389ms/step - loss: 0.0508 - accuracy: 0.9815 - precision: 0.9964 - recall: 0.9786 - val_loss: 1.0983 - val_accuracy: 0.6680 - val_precision: 0.9952 - val_recall: 0.5493

# %% [markdown]
# ## Step 7. 평가 및 훈련 결과 시각화

# %%
loss, acc, prec, rec = resnet_model.evaluate(test_ds)
# Out:
# 20/20 [==============================] - 5s 250ms/step - loss: 0.7603 - accuracy: 0.7564 - precision: 0.9474 - recall: 0.6462

# %%
fig, ax = plt.subplots(2, 2, figsize=(20, 12))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
keys = list(history.history.keys())

metrics_to_plot = ['precision', 'recall', 'accuracy', 'loss']

# Plot the specified metrics
plt.figure(figsize=(15, 8))
for metric in metrics_to_plot:
    plt.plot(history.history[metric], label=metric)

plt.title('Training Metrics Over Epochs')
plt.xlabel('Epoch')
plt.legend()
plt.show()

# %% [markdown]
# ## Ablation study
# - Resnet model, epoch(10), batch size(16), stride(1), dropout(0.5), augmentation(horizontal): Accuracy = 0.746
# - Resnet model, epoch(40), batch size(32), stride(1), dropout(0.5), augmentation(horizontal): Accuracy = 0.631
# - Resnet model, epoch(20), batch size(32), stride(1), dropout(0.5), augmentation(horizontal): Accuracy = 0.8045
# - Resnet model, epoch(25), batch size(32), stride(1), dropout(0.5), augmentation(horizontal): **Accuracy = 0.8157**
# - Resnet model, epoch(30), batch size(32), stride(2), dropout(0.5), augmentation(horizontal): Accuracy = 0.7564

# %% [markdown]
# ## 회고
# 기존 CNN 모델을 Resnet으로 구현하여 학습해보았다. 모델을 만들고 시각화하여 학습 진행 양상을 면밀하게 분서갷보았다. Ablation study를 통해 성능이 잘 나오는 하이퍼 파라미터를 셋팅할 수 있었다.
